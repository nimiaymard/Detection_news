# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\user\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\user\anaconda3\Lib\site-packages)

# %%
import pandas as pd

# %%
def load_data(input_filepath):
    data = pd.read_csv(input_filepath)
    return data

# %%
input_filepath= '../data/processed_fake_news/mabs_transformed.csv'
load_data(input_filepath)
# Out:
#                          id  \
# 0      gossipcop-2493749932
# 1      gossipcop-4580247171
# 2       gossipcop-941805037
# 3      gossipcop-2547891536
# 4      gossipcop-5476631226
# ...                     ...
# 21402        politifact6931
# 21403       politifact13619
# 21404         politifact329
# 21405        politifact4720
# 21406          politifact52
#
#                                                 news_url  \
# 0      www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1      hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2      variety.com/2017/biz/news/tax-march-donald-tru...
# 3      www.dailymail.co.uk/femail/article-3499192/Do-...
# 4      variety.com/2018/film/news/list-2018-oscar-nom...
# ...                                                  ...
# 21402  http://www.politifact.com/truth-o-meter/promis...
# 21403  http://www.cnn.com/2017/01/05/politics/border-...
# 21404  https://web.archive.org/web/20080131000131/htt...
# ...
