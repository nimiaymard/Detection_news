# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
def load_data(input_filepath):
    data = pd.read_csv(input_filepath)
    return data

# %%
input_filepath= '../data/processed/mabs_transformed.csv'
load_data(input_filepath)
# Out:
#                   id                                           news_url  \
# 0    politifact14885  www.breakingnews247.net/59bc13819a723/world-s-...
# 1     politifact1106  http://frwebgate.access.gpo.gov/cgi-bin/getdoc...
# 2     politifact1678  http://abcnews.go.com/ThisWeek/video/supreme-c...
# 3      politifact370  http://tonto.eia.doe.gov/dnav/pet/pet_move_wkl...
# 4    politifact15263  http://sciencevibe.com/2018/04/11/dying-78-yea...
# ..               ...                                                ...
# 990  politifact14090  http://breaking13news.com/malia-obama-arrested...
# 991   politifact6641                            http://www.bls.gov/ces/
# 992  politifact14904  https://web.archive.org/web/20180109225217/htt...
# 993   politifact4555  http://www.cq.com/doc/newsmakertranscripts-395...
# 994    politifact691  https://web.archive.org/web/20080911193042/htt...
#
#                                             Title_news Annotations  \
# ...
